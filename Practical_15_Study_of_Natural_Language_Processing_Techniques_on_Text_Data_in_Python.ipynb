# %% [markdown]
# <a href="https://colab.research.google.com/github/notorious0789/Implementation-of-Natural-Language-Processing-NLP-Techniques-on-Text-Data/blob/main/Practical_15_Study_of_Natural_Language_Processing_Techniques_on_Text_Data_in_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Experiment 15
# ##Title: Natural Language Processing Techniques on Text Data in Python
# ##3 April 2026
# ##Apoorba Chatterjee
# ##PRN: 25070123020
# ##ENTC A1

# %%
# Tokenization
import nltk # Natural Langaueg Tool Kit
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
from nltk.tokenize import word_tokenize
text = "Inter-Continental Nuclear Air Defence System"
tokens = word_tokenize(text)
print(tokens)
print(type(tokens))
# Out:
# ['Inter-Continental', 'Nuclear', 'Air', 'Defence', 'System']
# <class 'list'>

# %%
# Sentences Tokenization
from nltk.tokenize import sent_tokenize
text = "Python is easy language. It is used widely in data science."
sentences = sent_tokenize(text)
print(sentences)
print(type(sentences))
# Out:
# ['Python is easy language.', 'It is used widely in data science.']
# <class 'list'>

# %%
# Stop Word Removal
from nltk.corpus import stopwords
stop_words = set(stopwords.words('english'))
words = word_tokenize(text)
filtered_words = [word for word in words if word.lower() not in stop_words]
print(filtered_words)
# Out:
# ['Python', 'easy', 'language', '.', 'used', 'widely', 'data', 'science', '.']

# %%
# Steming
from nltk.stem import PorterStemmer
stemmer = PorterStemmer()
words = ["playing","studies","Coding",]
for w in words:
  print(stemmer.stem(w))
# Out:
# play
# studi
# code

# %%
# Lemmmatization
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
print(lemmatizer.lemmatize("Graph"))
# Out:
# Graph

# %%
# Part-Of-Speech
import nltk
nltk.download('averaged_perceptron_tagger')
nltk.download('averaged_perceptron_tagger_eng')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!
# True

# %%
from nltk import pos_tag
words = word_tokenize("Agni -V Is Inter-Continental Nuclear Air Defence Missile")
pos_tags = pos_tag(words)
print(pos_tags)
print(type(pos_tags))
# Out:
# [('Agni', 'NNP'), ('-V', 'NNP'), ('Is', 'VBZ'), ('Inter-Continental', 'JJ'), ('Nuclear', 'NNP'), ('Air', 'NNP'), ('Defence', 'NNP'), ('Missile', 'NN')]
# <class 'list'>

# %%
#  Word Frequency Counter
from nltk.probability import FreqDist
words = word_tokenize(text)
fd = FreqDist(words)
print("\n",fd.most_common(),"\n")
# Out:
#  [('is', 2), ('.', 2), ('Python', 1), ('easy', 1), ('language', 1), ('It', 1), ('used', 1), ('widely', 1), ('in', 1), ('data', 1), ('science', 1)]
